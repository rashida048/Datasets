# %%
import pandas as pd

# %%
df=pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df.iloc[3]
# Out:
# YEAR                       2013
# Make                 MITSUBISHI
# Model                    i-MiEV
# Size                 SUBCOMPACT
# (kW)                         49
# Unnamed: 5                   A1
# TYPE                          B
# CITY (kWh/100 km)          16.9
# HWY (kWh/100 km)           21.4
# COMB (kWh/100 km)          18.7
# CITY (Le/100 km)            1.9
# HWY (Le/100 km)             2.4
# COMB (Le/100 km)            2.1
# (g/km)                        0
# RATING                      NaN
# (km)                        100
# TIME (h)                      7
# Name: 3, dtype: object

# %%
df.iloc[:, 2]
# Out:
# 0                              i-MiEV
# 1                                LEAF
# 2                      FOCUS ELECTRIC
# 3                              i-MiEV
# 4                                LEAF
# 5     FORTWO ELECTRIC DRIVE CABRIOLET
# 6         FORTWO ELECTRIC DRIVE COUPE
# 7            MODEL S (40 kWh battery)
# 8            MODEL S (60 kWh battery)
# 9            MODEL S (85 kWh battery)
# 10                MODEL S PERFORMANCE
# 11                           SPARK EV
# 12                     FOCUS ELECTRIC
# 13                             i-MiEV
# 14                               LEAF
# 15    FORTWO ELECTRIC DRIVE CABRIOLET
# 16        FORTWO ELECTRIC DRIVE COUPE
# 17           MODEL S (60 kWh battery)
# 18           MODEL S (85 kWh battery)
# 19                MODEL S PERFORMANCE
# 20                                 i3
# 21                           SPARK EV
# 22                     FOCUS ELECTRIC
# 23                            SOUL EV
# 24                             i-MiEV
# ...

# %%
df.iloc[10:15]
# Out:
#     YEAR        Make                Model        Size  (kW) Unnamed: 5 TYPE  \
# 10  2013       TESLA  MODEL S PERFORMANCE   FULL-SIZE   310         A1    B
# 11  2014   CHEVROLET             SPARK EV  SUBCOMPACT   104         A1    B
# 12  2014        FORD       FOCUS ELECTRIC     COMPACT   107         A1    B
# 13  2014  MITSUBISHI               i-MiEV  SUBCOMPACT    49         A1    B
# 14  2014      NISSAN                 LEAF    MID-SIZE    80         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 10               23.9              23.2               23.6               2.7
# 11               16.0              19.6               17.8               1.8
# 12               19.0              21.1               20.0               2.1
# 13               16.9              21.4               18.7               1.9
# 14               16.5              20.8               18.4               1.9
#
# ...

# %%
df.iloc[10:15, 3:9]
# Out:
#           Size  (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)
# 10   FULL-SIZE   310         A1    B               23.9              23.2
# 11  SUBCOMPACT   104         A1    B               16.0              19.6
# 12     COMPACT   107         A1    B               19.0              21.1
# 13  SUBCOMPACT    49         A1    B               16.9              21.4
# 14    MID-SIZE    80         A1    B               16.5              20.8

# %%
df.iloc[[2, 6, 10, 25, 28, 33]]
# Out:
#     YEAR    Make                        Model        Size  (kW) Unnamed: 5  \
# 2   2013    FORD               FOCUS ELECTRIC     COMPACT   107         A1
# 6   2013   SMART  FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35         A1
# 10  2013   TESLA          MODEL S PERFORMANCE   FULL-SIZE   310         A1
# 25  2015  NISSAN                         LEAF    MID-SIZE    80         A1
# 28  2015   TESLA     MODEL S (60 kWh battery)   FULL-SIZE   283         A1
# 33  2015   TESLA            MODEL S P85D/P90D   FULL-SIZE   515         A1
#
#    TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 2     B               19.0              21.1               20.0
# 6     B               17.2              22.5               19.6
# 10    B               23.9              23.2               23.6
# 25    B               16.5              20.8               18.4
# 28    B               22.2              21.7               21.9
# ...

# %%
df.iloc[[2, 6, 10, 25, 28, 33], [0, 1, 6, 10]]
# Out:
#     YEAR    Make TYPE  CITY (Le/100 km)
# 2   2013    FORD    B               2.1
# 6   2013   SMART    B               1.9
# 10  2013   TESLA    B               2.7
# 25  2015  NISSAN    B               1.9
# 28  2015   TESLA    B               2.5
# 33  2015   TESLA    B               2.6

# %%
df.iloc[[2, 6, 10, 25, 28, 33], 1:6]
# Out:
#       Make                        Model        Size  (kW) Unnamed: 5
# 2     FORD               FOCUS ELECTRIC     COMPACT   107         A1
# 6    SMART  FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35         A1
# 10   TESLA          MODEL S PERFORMANCE   FULL-SIZE   310         A1
# 25  NISSAN                         LEAF    MID-SIZE    80         A1
# 28   TESLA     MODEL S (60 kWh battery)   FULL-SIZE   283         A1
# 33   TESLA            MODEL S P85D/P90D   FULL-SIZE   515         A1

# %%
df.loc[0:5]
# Out:
#    YEAR        Make                            Model        Size  (kW)  \
# 0  2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 1  2012      NISSAN                             LEAF    MID-SIZE    80
# 2  2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 3  2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 4  2013      NISSAN                             LEAF    MID-SIZE    80
# 5  2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
#
#   Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 0         A1    B               16.9              21.4               18.7
# 1         A1    B               19.3              23.0               21.1
# 2         A1    B               19.0              21.1               20.0
# 3         A1    B               16.9              21.4               18.7
# 4         A1    B               19.3              23.0               21.1
# ...

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df = df.set_index('YEAR')

# %%
df.head()
# Out:
#             Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# YEAR
# 2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#       CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2012               16.9              21.4               18.7
# 2012               19.3              23.0               21.1
# 2013               19.0              21.1               20.0
# 2013               16.9              21.4               18.7
# 2013               19.3              23.0               21.1
#
#       CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  \
# YEAR
# 2012               1.9              2.4               2.1       0     NaN
# ...

# %%
df.loc[2013]
# Out:
#             Make                            Model        Size  (kW)  \
# YEAR
# 2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2013      NISSAN                             LEAF    MID-SIZE    80
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
# 2013       TESLA              MODEL S PERFORMANCE   FULL-SIZE   310
#
#      Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2013         A1    B               19.0              21.1               20.0
# 2013         A1    B               16.9              21.4               18.7
# ...

# %%
df.loc[[2012, 2013, 2016]]
# Out:
#             Make                            Model                   Size  \
# YEAR
# 2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 2012      NISSAN                             LEAF               MID-SIZE
# 2013        FORD                   FOCUS ELECTRIC                COMPACT
# 2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 2013      NISSAN                             LEAF               MID-SIZE
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 2016         BMW                               i3             SUBCOMPACT
# ...

# %%
df.loc[2012:2016]
# Out:
#             Make                            Model                   Size  \
# YEAR
# 2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 2012      NISSAN                             LEAF               MID-SIZE
# 2013        FORD                   FOCUS ELECTRIC                COMPACT
# 2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 2013      NISSAN                             LEAF               MID-SIZE
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 2014   CHEVROLET                         SPARK EV             SUBCOMPACT
# ...

# %%
df.loc[2012:2014, 'Make':'(kW)']
# Out:
#             Make                            Model        Size  (kW)
# YEAR
# 2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2012      NISSAN                             LEAF    MID-SIZE    80
# 2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 2013      NISSAN                             LEAF    MID-SIZE    80
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
# 2013       TESLA              MODEL S PERFORMANCE   FULL-SIZE   310
# 2014   CHEVROLET                         SPARK EV  SUBCOMPACT   104
# 2014        FORD                   FOCUS ELECTRIC     COMPACT   107
# ...

# %%
df.loc[2012:2014, ['Make', 'Model', 'TYPE', '(kW)', '(km)']]
# Out:
#             Make                            Model TYPE  (kW)  (km)
# YEAR
# 2012  MITSUBISHI                           i-MiEV    B    49   100
# 2012      NISSAN                             LEAF    B    80   117
# 2013        FORD                   FOCUS ELECTRIC    B   107   122
# 2013  MITSUBISHI                           i-MiEV    B    49   100
# 2013      NISSAN                             LEAF    B    80   117
# 2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET    B    35   109
# 2013       SMART      FORTWO ELECTRIC DRIVE COUPE    B    35   109
# 2013       TESLA         MODEL S (40 kWh battery)    B   270   224
# 2013       TESLA         MODEL S (60 kWh battery)    B   270   335
# 2013       TESLA         MODEL S (85 kWh battery)    B   270   426
# 2013       TESLA              MODEL S PERFORMANCE    B   310   426
# 2014   CHEVROLET                         SPARK EV    B   104   131
# 2014        FORD                   FOCUS ELECTRIC    B   107   122
# ...

# %%
df.loc[[2012, 2014, 2016], ['Make', 'Model', 'TYPE', '(kW)', '(km)']]
# Out:
#             Make                            Model TYPE  (kW)  (km)
# YEAR
# 2012  MITSUBISHI                           i-MiEV    B    49   100
# 2012      NISSAN                             LEAF    B    80   117
# 2014   CHEVROLET                         SPARK EV    B   104   131
# 2014        FORD                   FOCUS ELECTRIC    B   107   122
# 2014  MITSUBISHI                           i-MiEV    B    49   100
# 2014      NISSAN                             LEAF    B    80   135
# 2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET    B    35   109
# 2014       SMART      FORTWO ELECTRIC DRIVE COUPE    B    35   109
# 2014       TESLA         MODEL S (60 kWh battery)    B   225   335
# 2014       TESLA         MODEL S (85 kWh battery)    B   270   426
# 2014       TESLA              MODEL S PERFORMANCE    B   310   426
# 2016         BMW                               i3    B   125   130
# 2016   CHEVROLET                         SPARK EV    B   104   131
# ...

# %%
df.loc[df['Make']=='FORD']
# Out:
#       Make           Model     Size  (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  \
# YEAR
# 2013  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
# 2014  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
# 2015  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
# 2016  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
#
#       HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# YEAR
# 2013              21.1               20.0               2.1              2.4
# 2014              21.1               20.0               2.1              2.4
# 2015              21.1               20.0               2.1              2.4
# 2016              21.1               20.0               2.1              2.4
#
#       COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# YEAR
# 2013               2.2       0     NaN   122         4
# 2014               2.2       0     NaN   122         4
# ...

# %%
df[df['Make']=='FORD']
# Out:
#       Make           Model     Size  (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  \
# YEAR
# 2013  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
# 2014  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
# 2015  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
# 2016  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B               19.0
#
#       HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# YEAR
# 2013              21.1               20.0               2.1              2.4
# 2014              21.1               20.0               2.1              2.4
# 2015              21.1               20.0               2.1              2.4
# 2016              21.1               20.0               2.1              2.4
#
#       COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# YEAR
# 2013               2.2       0     NaN   122         4
# 2014               2.2       0     NaN   122         4
# ...

# %%
df.loc[df['Make']=='FORD', 'Make':'TYPE']
# Out:
#       Make           Model     Size  (kW) Unnamed: 5 TYPE
# YEAR
# 2013  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B
# 2014  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B
# 2015  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B
# 2016  FORD  FOCUS ELECTRIC  COMPACT   107         A1    B

# %%
df[df['Make']=='TESLA']
# Out:
#        Make                        Model            Size  (kW) Unnamed: 5  \
# YEAR
# 2013  TESLA     MODEL S (40 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA     MODEL S (60 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA     MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA          MODEL S PERFORMANCE       FULL-SIZE   310         A1
# 2014  TESLA     MODEL S (60 kWh battery)       FULL-SIZE   225         A1
# 2014  TESLA     MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 2014  TESLA          MODEL S PERFORMANCE       FULL-SIZE   310         A1
# 2015  TESLA     MODEL S (60 kWh battery)       FULL-SIZE   283         A1
# 2015  TESLA     MODEL S (70 kWh battery)       FULL-SIZE   283         A1
# 2015  TESLA  MODEL S (85/90 kWh battery)       FULL-SIZE   283         A1
# 2015  TESLA                  MODEL S 70D       FULL-SIZE   280         A1
# 2015  TESLA              MODEL S 85D/90D       FULL-SIZE   280         A1
# ...

# %%
df[(df['Make']=='TESLA') &(df['Model']=='MODEL S 70D')]
# Out:
#        Make        Model       Size  (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  \
# YEAR
# 2015  TESLA  MODEL S 70D  FULL-SIZE   280         A1    B               20.8
# 2016  TESLA  MODEL S 70D  FULL-SIZE   386         A1    B               20.8
#
#       HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# YEAR
# 2015              20.6               20.7               2.3              2.3
# 2016              20.6               20.7               2.3              2.3
#
#       COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# YEAR
# 2015               2.3       0     NaN   386        12
# 2016               2.3       0    10.0   386        12

# %%
df.loc[(df['Make']=='TESLA') &(df['Model']=='MODEL S 70D'), ['Make','Model', 'Size', '(kW)']]
# Out:
#        Make        Model       Size  (kW)
# YEAR
# 2015  TESLA  MODEL S 70D  FULL-SIZE   280
# 2016  TESLA  MODEL S 70D  FULL-SIZE   386

# %%
df.loc[df['Make'].apply(lambda x: len(x)==5)]
# Out:
#        Make                            Model            Size  (kW) Unnamed: 5  \
# YEAR
# 2013  SMART  FORTWO ELECTRIC DRIVE CABRIOLET      TWO-SEATER    35         A1
# 2013  SMART      FORTWO ELECTRIC DRIVE COUPE      TWO-SEATER    35         A1
# 2013  TESLA         MODEL S (40 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA         MODEL S (60 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA         MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA              MODEL S PERFORMANCE       FULL-SIZE   310         A1
# 2014  SMART  FORTWO ELECTRIC DRIVE CABRIOLET      TWO-SEATER    35         A1
# 2014  SMART      FORTWO ELECTRIC DRIVE COUPE      TWO-SEATER    35         A1
# 2014  TESLA         MODEL S (60 kWh battery)       FULL-SIZE   225         A1
# 2014  TESLA         MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 2014  TESLA              MODEL S PERFORMANCE       FULL-SIZE   310         A1
# ...

# %%
df.loc[df['Make'].apply(lambda x: len(x)==5), 'Make':'TYPE']
# Out:
#        Make                            Model            Size  (kW) Unnamed: 5  \
# YEAR
# 2013  SMART  FORTWO ELECTRIC DRIVE CABRIOLET      TWO-SEATER    35         A1
# 2013  SMART      FORTWO ELECTRIC DRIVE COUPE      TWO-SEATER    35         A1
# 2013  TESLA         MODEL S (40 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA         MODEL S (60 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA         MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 2013  TESLA              MODEL S PERFORMANCE       FULL-SIZE   310         A1
# 2014  SMART  FORTWO ELECTRIC DRIVE CABRIOLET      TWO-SEATER    35         A1
# 2014  SMART      FORTWO ELECTRIC DRIVE COUPE      TWO-SEATER    35         A1
# 2014  TESLA         MODEL S (60 kWh battery)       FULL-SIZE   225         A1
# 2014  TESLA         MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 2014  TESLA              MODEL S PERFORMANCE       FULL-SIZE   310         A1
# ...
